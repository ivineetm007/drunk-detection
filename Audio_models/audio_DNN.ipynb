# %%
import os
import tqdm
import sys
import keras

# %%
LENGTH=10 #in secs
FEATURE_DIM = 1582 # opensmile feature dimension for an input chunk

# %%
# USER INPUT- features_dir
# features_dir- path to save or load vgg face features
curr=os.getcwd()
repo_path=curr.split('/code')[0]
data_path=repo_path+'/DIFv2'
features_path=repo_path+'/features'#  Folder containing all features audio and video
features_dir=features_path+'/'+str(LENGTH)+'/opensmile'# Path to save/load opensmile features

# %% [markdown]
# # Generator and data split code

# %%
import csv
'''
Input-  csv_file
Output- partition train, val test. Each partition consists of list of .npy files and dictionary of labels.
'''
def train_test_split(csv_path):
    label={'Drunk':1, 'Sober':0}
    partition={}
    train={}
    val={}
    test={}
    
    train_list=[]
    val_list=[]
    test_list=[]
    train_label={}
    val_label={}
    test_label={}
    
    with open(csv_path) as csvfile:
        reader=csv.reader(csvfile,delimiter=',')
        for row in reader:
            filename=row[2]
            filename=filename[:-4]
            if row[0]=='train':
                train_label[filename]=label[row[1]]
                train_list.append(filename)
            elif row[0]=='val':
                val_label[filename]=label[row[1]]
                val_list.append(filename)
            elif row[0]=='test':
                test_label[filename]=label[row[1]]
                test_list.append(filename)
            else:
                print("Error in label")
                return None
    train['list']=train_list
    val['list']=val_list
    test['list']=test_list
    
    train['label']=train_label
    val['label']=val_label
    test['label']=test_label
    
    partition['train']=train
    partition['val']=val
    partition['test']=test
    
    return partition

def count_classes(d):
    values=list(d.values())
    zeros=values.count(0)
    return (zeros,len(values)-zeros)

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels,datapath, batch_size=32, dim=(1582),n_classes=2, shuffle=True):
        'Initialization'        
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        #self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()
        self.path=datapath

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        import gc
        gc.collect()
        return X, y
    
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size), dtype=int)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            X[i,] = np.load(self.path+'/' + ID + '.npy')

            # Store class
            y[i] = self.labels[ID]

        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# # Build Model

# %% [markdown]
# 3.1 Model creation and summary
#
# ordering of batch norm and dropout
# https://stackoverflow.com/questions/39691902/ordering-of-batch-normalization-and-dropout

# %%
from keras.optimizers import Adam
from keras.models import Model
from keras.models import load_model
from keras.layers import Dense, Input, Dropout, LSTM, Activation,BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
import keras
from time import time
import gc
import numpy as np
keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
def create_model(num_class,dense1_units,dense2_units,dropout,input_shape=(1582,)):
    """
        Two layer DNN
    """
    X=Input(shape=input_shape)
    norm=BatchNormalization()(X)
    layer1=Dense(dense1_units, activation='relu')(norm)
    drop=Dropout(rate=dropout)(layer1)
    layer2=Dense(dense2_units, activation='relu')(drop)
    drop=Dropout(rate=dropout)(layer2)
    prob=Dense(num_class, activation='sigmoid')(layer2)
    return Model(inputs = X, outputs = prob)

def basic_model(num_class,input_shape=(1582,)):
    """
        Single layer DNN
    """
    X=Input(shape=input_shape)
    prob=Dense(num_class, activation='sigmoid')(X)
    return Model(inputs = X, outputs = prob)

# %%
dense1=256
dense2=128
#dense3=128
dropout=.2
hp=2
class_num=2
model=create_model(class_num,dense1,dense2,dropout,input_shape=(FEATURE_DIM,))
#USER INPUT, path to save/ load model
model_path=repo_path+'/saved_models/audio_open/'+str(LENGTH)+'/hp'+str(hp)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1582)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1582)              6328
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               405248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 444,730
# Trainable params: 441,566
# Non-trainable params: 3,164
# _________________________________________________________________

# %%
def load_keras_model(path):
    if os.path.isfile(path):
        return load_model(path)
#Loading data filenames split
#USER INPUT
partition=train_test_split(repo_path+'/DIFv2/10/train_test_sets/1/split_4540_642_948.csv')# or enter path to the split.csv in the parent directory 
print("Number of training examples ")
print(len(partition['train']['list']))
print("Number of validation examples ")
print(len(partition['val']['list']))

params = {'datapath':features_dir ,
          'dim': (FEATURE_DIM,),
          'batch_size': 64,
          'n_classes': 2,
          'shuffle': True}
    
#weights for imbalance classes
count=count_classes(partition['train']['label'])
print("Class instances in training class.\n Sober:",count[0]," Drunk:",count[1])
weight_0=float(count[0]+count[1])/float(count[0])
weight_1=float(count[0]+count[1])/float(count[1])
class_weight={0:weight_0, 1:weight_1}

#instances in val set
count=count_classes(partition['val']['label'])
print("Class instances in val class.\n Sober:",count[0]," Drunk:",count[1])

#instances in test set
count=count_classes(partition['test']['label'])
print("Class instances in test class.\n Sober:",count[0]," Drunk:",count[1])
# Out:
# Number of training examples
# 4540
# Number of validation examples
# 642
# Class instances in training class.
#  Sober: 1045  Drunk: 3495
# Class instances in val class.
#  Sober: 321  Drunk: 321
# Class instances in test class.
#  Sober: 306  Drunk: 642

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=["accuracy"])

#saving best model
checkpoint = ModelCheckpoint(model_path+'/model-{epoch:03d}-{val_acc:03f}.h5', verbose=1, monitor='val_acc',save_best_only=False, mode='max',period=5)


#tensorboard
tensorboard = TensorBoard(log_dir=model_path+"/log/{}".format(time()))

train_generator=DataGenerator(partition['train']['list'],partition['train']['label'], **params)
val_generator=DataGenerator(partition['val']['list'],partition['val']['label'], **params)
print("generator created")
model.fit_generator(generator=train_generator,epochs=80,validation_data=val_generator,
                    use_multiprocessing=True,
                    workers=6,callbacks=[checkpoint,tensorboard],class_weight=class_weight)
# Out:
# generator created
# Epoch 1/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.3773 - acc: 0.9198 - val_loss: 0.5590 - val_acc: 0.8383
# Epoch 2/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.1730 - acc: 0.9642 - val_loss: 0.4436 - val_acc: 0.8625
# Epoch 3/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.1217 - acc: 0.9732 - val_loss: 0.8580 - val_acc: 0.8234
# Epoch 4/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0912 - acc: 0.9813 - val_loss: 0.9090 - val_acc: 0.8352
# Epoch 5/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0889 - acc: 0.9809 - val_loss: 1.0475 - val_acc: 0.8266
#
# Epoch 00005: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-005-0.826562.h5
# Epoch 6/80
# 70/70 [==============================] - 2s 24ms/step - loss: 0.0701 - acc: 0.9858 - val_loss: 0.9453 - val_acc: 0.8313
# Epoch 7/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0701 - acc: 0.9859 - val_loss: 1.1682 - val_acc: 0.8172
# Epoch 8/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0709 - acc: 0.9845 - val_loss: 1.0644 - val_acc: 0.8219
# Epoch 9/80
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0724 - acc: 0.9840 - val_loss: 0.9674 - val_acc: 0.8398
# Epoch 10/80
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0504 - acc: 0.9898 - val_loss: 0.9640 - val_acc: 0.8391
#
# Epoch 00010: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-010-0.839063.h5
# Epoch 11/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0418 - acc: 0.9907 - val_loss: 1.0926 - val_acc: 0.8398
# Epoch 12/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0420 - acc: 0.9910 - val_loss: 1.3903 - val_acc: 0.8313
# Epoch 13/80
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0451 - acc: 0.9906 - val_loss: 1.2470 - val_acc: 0.8422
# Epoch 14/80
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0351 - acc: 0.9924 - val_loss: 1.2450 - val_acc: 0.8422
# Epoch 15/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0501 - acc: 0.9901 - val_loss: 1.3282 - val_acc: 0.8266
#
# Epoch 00015: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-015-0.826562.h5
# Epoch 16/80
# 70/70 [==============================] - 2s 36ms/step - loss: 0.0391 - acc: 0.9915 - val_loss: 1.5489 - val_acc: 0.8227
# Epoch 17/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0588 - acc: 0.9878 - val_loss: 1.1491 - val_acc: 0.8547
# Epoch 18/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0507 - acc: 0.9893 - val_loss: 1.5628 - val_acc: 0.8258
# Epoch 19/80
# Epoch 18/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0388 - acc: 0.9913 - val_loss: 1.0722 - val_acc: 0.8430
# Epoch 20/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0217 - acc: 0.9961 - val_loss: 1.6690 - val_acc: 0.8273
#
# Epoch 00020: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-020-0.827344.h5
# Epoch 21/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0240 - acc: 0.9941 - val_loss: 2.0775 - val_acc: 0.8023
# Epoch 22/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0400 - acc: 0.9923 - val_loss: 1.1586 - val_acc: 0.8453
# Epoch 23/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0920 - acc: 0.9888 - val_loss: 1.1078 - val_acc: 0.8594
# Epoch 24/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0749 - acc: 0.9863 - val_loss: 1.4864 - val_acc: 0.8086
# Epoch 25/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0336 - acc: 0.9927 - val_loss: 1.3800 - val_acc: 0.8328
#
# Epoch 00025: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-025-0.832812.h5
# Epoch 26/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0268 - acc: 0.9931 - val_loss: 1.4721 - val_acc: 0.8344
# Epoch 27/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0269 - acc: 0.9943 - val_loss: 1.3191 - val_acc: 0.8562
# Epoch 28/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0262 - acc: 0.9945 - val_loss: 1.4176 - val_acc: 0.8484
# Epoch 29/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0141 - acc: 0.9965 - val_loss: 1.3434 - val_acc: 0.8531
# Epoch 30/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0216 - acc: 0.9951 - val_loss: 1.2856 - val_acc: 0.8430
#
# Epoch 00030: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-030-0.842969.h5
# Epoch 31/80
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0220 - acc: 0.9960 - val_loss: 1.2911 - val_acc: 0.8625
# Epoch 32/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0212 - acc: 0.9950 - val_loss: 1.3376 - val_acc: 0.8562
# Epoch 33/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0156 - acc: 0.9968 - val_loss: 1.5622 - val_acc: 0.8477
# Epoch 34/80
# 70/70 [==============================] - 2s 36ms/step - loss: 0.0162 - acc: 0.9962 - val_loss: 1.4534 - val_acc: 0.8586
# Epoch 35/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0188 - acc: 0.9961 - val_loss: 1.2241 - val_acc: 0.8703
#
# Epoch 00035: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-035-0.870313.h5
# Epoch 36/80
# 68/70 [============================>.] - ETA: 0s - loss: 0.0175 - acc: 0.9963
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0177 - acc: 0.9962 - val_loss: 2.4484 - val_acc: 0.8063
# Epoch 37/80
#
# 70/70 [==============================] - 2s 31ms/step - loss: 0.0456 - acc: 0.9920 - val_loss: 1.6417 - val_acc: 0.8391
# Epoch 38/80
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0225 - acc: 0.9950 - val_loss: 1.4481 - val_acc: 0.8406
# Epoch 39/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0217 - acc: 0.9960 - val_loss: 1.5040 - val_acc: 0.8320
# Epoch 40/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0151 - acc: 0.9971 - val_loss: 1.5268 - val_acc: 0.8320
#
# Epoch 00040: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-040-0.832031.h5
# Epoch 41/80
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0125 - acc: 0.9970 - val_loss: 1.7302 - val_acc: 0.8180
# Epoch 42/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0120 - acc: 0.9972 - val_loss: 1.5896 - val_acc: 0.8242
# Epoch 43/80
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0227 - acc: 0.9963 - val_loss: 1.6505 - val_acc: 0.8320
# Epoch 44/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0529 - acc: 0.9941 - val_loss: 1.8704 - val_acc: 0.8070
# Epoch 45/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0207 - acc: 0.9951 - val_loss: 1.8685 - val_acc: 0.8180
#
# Epoch 00045: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-045-0.817969.h5
# Epoch 46/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0237 - acc: 0.9956 - val_loss: 1.7445 - val_acc: 0.8148
# Epoch 47/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0169 - acc: 0.9961 - val_loss: 1.5856 - val_acc: 0.8266
# Epoch 48/80
# Epoch 47/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0156 - acc: 0.9968 - val_loss: 1.5789 - val_acc: 0.8352
# Epoch 49/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0121 - acc: 0.9972 - val_loss: 1.8126 - val_acc: 0.8383
# Epoch 50/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0074 - acc: 0.9987 - val_loss: 1.7916 - val_acc: 0.8461
#
# Epoch 00050: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-050-0.846094.h5
# Epoch 51/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0094 - acc: 0.9971 - val_loss: 1.6298 - val_acc: 0.8422
# Epoch 52/80
# Epoch 51/80
# Epoch 51/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0104 - acc: 0.9974 - val_loss: 1.7667 - val_acc: 0.8398
# Epoch 53/80
# 70/70 [==============================] - 2s 36ms/step - loss: 0.0186 - acc: 0.9964 - val_loss: 1.4879 - val_acc: 0.8438
# Epoch 54/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0269 - acc: 0.9952 - val_loss: 1.7154 - val_acc: 0.8391
# Epoch 55/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0203 - acc: 0.9959 - val_loss: 1.7939 - val_acc: 0.8406
#
# Epoch 00055: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-055-0.840625.h5
# Epoch 56/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0075 - acc: 0.9978 - val_loss: 1.7387 - val_acc: 0.8453
# Epoch 57/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0097 - acc: 0.9982 - val_loss: 1.8909 - val_acc: 0.8289
# Epoch 58/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0149 - acc: 0.9975 - val_loss: 1.6969 - val_acc: 0.8375
# Epoch 59/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0060 - acc: 0.9989 - val_loss: 1.7592 - val_acc: 0.8438
# Epoch 60/80
# 70/70 [==============================] - 2s 31ms/step - loss: 0.0038 - acc: 0.9988 - val_loss: 1.5469 - val_acc: 0.8508
#
# Epoch 00060: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-060-0.850781.h5
# Epoch 61/80
# 70/70 [==============================] - 2s 31ms/step - loss: 0.0146 - acc: 0.9971 - val_loss: 1.8113 - val_acc: 0.8391
# Epoch 62/80
# Epoch 61/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0219 - acc: 0.9959 - val_loss: 1.7173 - val_acc: 0.8367
# Epoch 63/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0123 - acc: 0.9964 - val_loss: 1.7166 - val_acc: 0.8445
# Epoch 64/80
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0277 - acc: 0.9964 - val_loss: 1.6234 - val_acc: 0.8336
# Epoch 65/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0264 - acc: 0.9949 - val_loss: 2.5351 - val_acc: 0.7812
#
# Epoch 00065: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-065-0.781250.h5
# Epoch 66/80
# 70/70 [==============================] - 2s 32ms/step - loss: 0.0279 - acc: 0.9959 - val_loss: 1.6945 - val_acc: 0.8313
# Epoch 67/80
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0121 - acc: 0.9979 - val_loss: 1.8479 - val_acc: 0.8258
# Epoch 68/80
# 70/70 [==============================] - 2s 36ms/step - loss: 0.0090 - acc: 0.9984 - val_loss: 1.9042 - val_acc: 0.8320
# Epoch 69/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0153 - acc: 0.9980 - val_loss: 1.5364 - val_acc: 0.8594
# Epoch 70/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0058 - acc: 0.9988 - val_loss: 1.7600 - val_acc: 0.8438
#
# Epoch 00070: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-070-0.843750.h5
# Epoch 71/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0170 - acc: 0.9981 - val_loss: 2.0812 - val_acc: 0.8320
# Epoch 72/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0142 - acc: 0.9970 - val_loss: 1.5877 - val_acc: 0.8531
# Epoch 73/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0111 - acc: 0.9983 - val_loss: 1.4240 - val_acc: 0.8648
# Epoch 74/80
# Epoch 73/80
# 70/70 [==============================] - 2s 35ms/step - loss: 0.0053 - acc: 0.9987 - val_loss: 1.4139 - val_acc: 0.8641
# Epoch 75/80
# 70/70 [==============================] - 2s 34ms/step - loss: 0.0043 - acc: 0.9989 - val_loss: 1.5581 - val_acc: 0.8523
#
# Epoch 00075: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-075-0.852344.h5
# Epoch 76/80
# 70/70 [==============================] - 3s 36ms/step - loss: 0.0033 - acc: 0.9991 - val_loss: 1.6053 - val_acc: 0.8531
# Epoch 77/80
# 70/70 [==============================] - 4s 60ms/step - loss: 0.0070 - acc: 0.9987 - val_loss: 1.5802 - val_acc: 0.8539
# Epoch 78/80
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0168 - acc: 0.9973 - val_loss: 1.7221 - val_acc: 0.8531
# Epoch 79/80
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0135 - acc: 0.9969 - val_loss: 1.6681 - val_acc: 0.8453
# Epoch 80/80
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0192 - acc: 0.9951 - val_loss: 1.6022 - val_acc: 0.8523
#
# Epoch 00080: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp2/model-080-0.852344.h5

# %% [markdown]
# # Basic model

# %%
hp=3
class_num=2
model=basic_model(class_num,input_shape=(FEATURE_DIM,))
#USER INPUT, path to save/ load model
model_path=repo_path+'/saved_models/audio_open/'+str(LENGTH)+'/hp'+str(hp)
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 1582)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 3166
# =================================================================
# Total params: 3,166
# Trainable params: 3,166
# Non-trainable params: 0
# _________________________________________________________________

# %%
partition=train_test_split(repo_path+'/DIFv2/10/train_test_sets/1/split_4540_642_948.csv')
print("Number of training examples ")
print(len(partition['train']['list']))
print("Number of validation examples ")
print(len(partition['val']['list']))

params = {'datapath':features_dir ,
          'dim': (FEATURE_DIM,),
          'batch_size': 64,
          'n_classes': 2,
          'shuffle': True}
    
#weights for imbalance classes
count=count_classes(partition['train']['label'])
print("Class instances in training class.\n Sober:",count[0]," Drunk:",count[1])
weight_0=float(count[0]+count[1])/float(count[0])
weight_1=float(count[0]+count[1])/float(count[1])
class_weight={0:weight_0, 1:weight_1}

#instances in val set
count=count_classes(partition['val']['label'])
print("Class instances in val class.\n Sober:",count[0]," Drunk:",count[1])

#instances in test set
count=count_classes(partition['test']['label'])
print("Class instances in test class.\n Sober:",count[0]," Drunk:",count[1])
# Out:
# Number of training examples
# 4540
# Number of validation examples
# 642
# Class instances in training class.
#  Sober: 1045  Drunk: 3495
# Class instances in val class.
#  Sober: 321  Drunk: 321
# Class instances in test class.
#  Sober: 306  Drunk: 642

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=["accuracy"])

#saving best model
checkpoint = ModelCheckpoint(model_path+'/model-{epoch:03d}-{val_acc:03f}.h5', verbose=1, monitor='val_acc',save_best_only=False, mode='max',period=5)


#tensorboard
tensorboard = TensorBoard(log_dir=model_path+"/log/{}".format(time()))

train_generator=DataGenerator(partition['train']['list'],partition['train']['label'], **params)
val_generator=DataGenerator(partition['val']['list'],partition['val']['label'], **params)
print("generator created")
model.fit_generator(generator=train_generator,epochs=80,validation_data=val_generator,
                    use_multiprocessing=True,
                    workers=6,callbacks=[checkpoint,tensorboard],class_weight=class_weight)
# Out:
# generator created
# Epoch 1/80
# 70/70 [==============================] - 2s 35ms/step - loss: 14.9692 - acc: 0.6919 - val_loss: 7.0809 - val_acc: 0.5492
# Epoch 2/80
# 70/70 [==============================] - 2s 34ms/step - loss: 12.9183 - acc: 0.7188 - val_loss: 6.8895 - val_acc: 0.5570
# Epoch 3/80
# 70/70 [==============================] - 3s 38ms/step - loss: 11.8630 - acc: 0.7583 - val_loss: 6.4972 - val_acc: 0.5867
# Epoch 4/80
# 70/70 [==============================] - 2s 36ms/step - loss: 11.0016 - acc: 0.7712 - val_loss: 6.4710 - val_acc: 0.5867
# Epoch 5/80
# 70/70 [==============================] - 3s 37ms/step - loss: 10.6668 - acc: 0.7891 - val_loss: 6.2348 - val_acc: 0.6023
#
# Epoch 00005: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-005-0.602344.h5
# Epoch 6/80
# 70/70 [==============================] - 2s 23ms/step - loss: 10.3968 - acc: 0.7900 - val_loss: 6.2256 - val_acc: 0.5984
# Epoch 7/80
# 70/70 [==============================] - 3s 36ms/step - loss: 11.6091 - acc: 0.7665 - val_loss: 6.7465 - val_acc: 0.5711
# Epoch 8/80
# 70/70 [==============================] - 3s 37ms/step - loss: 10.4776 - acc: 0.7945 - val_loss: 6.5979 - val_acc: 0.5828
# Epoch 9/80
# 70/70 [==============================] - 3s 36ms/step - loss: 10.5154 - acc: 0.8050 - val_loss: 6.2417 - val_acc: 0.6039
# Epoch 10/80
# 70/70 [==============================] - 3s 38ms/step - loss: 10.3276 - acc: 0.7826 - val_loss: 6.0675 - val_acc: 0.6133
#
# Epoch 00010: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-010-0.613281.h5
# Epoch 11/80
# 70/70 [==============================] - 2s 36ms/step - loss: 9.9932 - acc: 0.8079 - val_loss: 6.3101 - val_acc: 0.5992
# Epoch 12/80
# 70/70 [==============================] - 2s 35ms/step - loss: 10.1987 - acc: 0.8127 - val_loss: 6.6127 - val_acc: 0.5828
# Epoch 13/80
# 70/70 [==============================] - 3s 37ms/step - loss: 10.1098 - acc: 0.7997 - val_loss: 6.2914 - val_acc: 0.5961
# Epoch 14/80
# 70/70 [==============================] - 3s 37ms/step - loss: 10.0714 - acc: 0.8156 - val_loss: 6.0592 - val_acc: 0.6141
# Epoch 15/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.7861 - acc: 0.8235 - val_loss: 5.9355 - val_acc: 0.6211
#
# Epoch 00015: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-015-0.621094.h5
# Epoch 16/80
# 70/70 [==============================] - 3s 39ms/step - loss: 10.1793 - acc: 0.8166 - val_loss: 5.9530 - val_acc: 0.6195
# Epoch 17/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.6845 - acc: 0.8193 - val_loss: 6.2379 - val_acc: 0.6047
# Epoch 18/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.6779 - acc: 0.8179 - val_loss: 6.1883 - val_acc: 0.6062
# Epoch 19/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.7100 - acc: 0.8233 - val_loss: 6.4624 - val_acc: 0.5898
# Epoch 20/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.9489 - acc: 0.8121 - val_loss: 6.0375 - val_acc: 0.6148
#
# Epoch 00020: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-020-0.614844.h5
# Epoch 21/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.8065 - acc: 0.8071 - val_loss: 6.2391 - val_acc: 0.6055
# Epoch 22/80
# 70/70 [==============================] - 3s 39ms/step - loss: 9.7658 - acc: 0.8132 - val_loss: 6.6627 - val_acc: 0.5758
# Epoch 23/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.8321 - acc: 0.8038 - val_loss: 6.1327 - val_acc: 0.6086
# Epoch 24/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.8434 - acc: 0.8099 - val_loss: 5.8349 - val_acc: 0.6297
# Epoch 25/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.8274 - acc: 0.8180 - val_loss: 5.8911 - val_acc: 0.6273
#
# Epoch 00025: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-025-0.627344.h5
# Epoch 26/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.4192 - acc: 0.8281 - val_loss: 5.9539 - val_acc: 0.6227
# Epoch 27/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.6470 - acc: 0.8223 - val_loss: 5.8388 - val_acc: 0.6312
# Epoch 28/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.4927 - acc: 0.8211 - val_loss: 5.9881 - val_acc: 0.6195
# Epoch 29/80
# 70/70 [==============================] - 3s 40ms/step - loss: 9.6001 - acc: 0.8210 - val_loss: 6.3566 - val_acc: 0.5969
# Epoch 30/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.9314 - acc: 0.8184 - val_loss: 5.8291 - val_acc: 0.6312
#
# Epoch 00030: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-030-0.631250.h5
# Epoch 31/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.5346 - acc: 0.8297 - val_loss: 6.2700 - val_acc: 0.6023
# Epoch 32/80
# 70/70 [==============================] - 3s 40ms/step - loss: 10.3927 - acc: 0.7985 - val_loss: 6.1407 - val_acc: 0.6109
# Epoch 33/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.4682 - acc: 0.8258 - val_loss: 5.7343 - val_acc: 0.6383
# Epoch 34/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.6391 - acc: 0.8138 - val_loss: 5.9230 - val_acc: 0.6234
# Epoch 35/80
# 70/70 [==============================] - 3s 39ms/step - loss: 9.5239 - acc: 0.8285 - val_loss: 5.8508 - val_acc: 0.6289
#
# Epoch 00035: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-035-0.628906.h5
# Epoch 36/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.4128 - acc: 0.8312 - val_loss: 6.1015 - val_acc: 0.6117
# Epoch 37/80
# 70/70 [==============================] - 2s 33ms/step - loss: 9.6818 - acc: 0.8237 - val_loss: 5.8998 - val_acc: 0.6273
# Epoch 38/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.3640 - acc: 0.8280 - val_loss: 5.8066 - val_acc: 0.6320
# Epoch 39/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.2974 - acc: 0.8283 - val_loss: 6.1244 - val_acc: 0.6117
# Epoch 40/80
# Epoch 39/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.5115 - acc: 0.8235 - val_loss: 5.8111 - val_acc: 0.6320
#
# Epoch 00040: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-040-0.632031.h5
# Epoch 41/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.4179 - acc: 0.8239 - val_loss: 6.3604 - val_acc: 0.5984
# Epoch 42/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.6294 - acc: 0.8210 - val_loss: 5.7050 - val_acc: 0.6383
# Epoch 43/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.4541 - acc: 0.8182 - val_loss: 6.3431 - val_acc: 0.5969
# Epoch 44/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.4648 - acc: 0.8301 - val_loss: 5.9399 - val_acc: 0.6234
# Epoch 45/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.3162 - acc: 0.8301 - val_loss: 5.7601 - val_acc: 0.6352
#
# Epoch 00045: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-045-0.635156.h5
# Epoch 46/80
# 70/70 [==============================] - 2s 32ms/step - loss: 9.3830 - acc: 0.8308 - val_loss: 6.0782 - val_acc: 0.6148
# Epoch 47/80
# 70/70 [==============================] - 2s 33ms/step - loss: 9.5255 - acc: 0.8184 - val_loss: 5.7627 - val_acc: 0.6359
# Epoch 48/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.7446 - acc: 0.8117 - val_loss: 5.9333 - val_acc: 0.6242
# Epoch 49/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.4380 - acc: 0.8259 - val_loss: 6.3927 - val_acc: 0.5969
# Epoch 50/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.3695 - acc: 0.8268 - val_loss: 5.9835 - val_acc: 0.6203
#
# Epoch 00050: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-050-0.620313.h5
# Epoch 51/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.5936 - acc: 0.8155 - val_loss: 5.9137 - val_acc: 0.6250
# Epoch 52/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.3568 - acc: 0.8279 - val_loss: 6.3309 - val_acc: 0.5984
# Epoch 53/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.2441 - acc: 0.8329 - val_loss: 5.8048 - val_acc: 0.6344
# Epoch 54/80
# 70/70 [==============================] - 2s 32ms/step - loss: 9.3293 - acc: 0.8227 - val_loss: 5.9595 - val_acc: 0.6211
# Epoch 55/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.4571 - acc: 0.8242 - val_loss: 5.9823 - val_acc: 0.6227
#
# Epoch 00055: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-055-0.622656.h5
# Epoch 56/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.2766 - acc: 0.8343 - val_loss: 6.1909 - val_acc: 0.6086
# Epoch 57/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.4140 - acc: 0.8292 - val_loss: 5.8927 - val_acc: 0.6281
# Epoch 58/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.3946 - acc: 0.8289 - val_loss: 6.1698 - val_acc: 0.6070
# Epoch 59/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.3284 - acc: 0.8294 - val_loss: 6.0831 - val_acc: 0.6172
# Epoch 60/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.3315 - acc: 0.8326 - val_loss: 5.8058 - val_acc: 0.6344
#
# Epoch 00060: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-060-0.634375.h5
# Epoch 61/80
# 70/70 [==============================] - 3s 37ms/step - loss: 9.2873 - acc: 0.8299 - val_loss: 6.3044 - val_acc: 0.6023
# Epoch 62/80
# 70/70 [==============================] - 2s 33ms/step - loss: 9.5425 - acc: 0.8196 - val_loss: 6.2973 - val_acc: 0.5977
# Epoch 63/80
# 70/70 [==============================] - ETA: 0s - loss: 9.3021 - acc: 0.832 - 3s 36ms/step - loss: 9.3225 - acc: 0.8307 - val_loss: 6.1927 - val_acc: 0.6094
# Epoch 64/80
# 70/70 [==============================] - 2s 33ms/step - loss: 9.1996 - acc: 0.8317 - val_loss: 5.7872 - val_acc: 0.6297
# Epoch 65/80
# 70/70 [==============================] - 3s 36ms/step - loss: 9.2286 - acc: 0.8385 - val_loss: 5.9948 - val_acc: 0.6203
#
# Epoch 00065: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-065-0.620313.h5
# Epoch 66/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.2475 - acc: 0.8299 - val_loss: 6.2913 - val_acc: 0.6039
# Epoch 67/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.5263 - acc: 0.8266 - val_loss: 6.6684 - val_acc: 0.5781
# Epoch 68/80
# 70/70 [==============================] - 2s 34ms/step - loss: 9.4188 - acc: 0.8344 - val_loss: 6.0607 - val_acc: 0.6141
# Epoch 69/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.2022 - acc: 0.8342 - val_loss: 6.0758 - val_acc: 0.6148
# Epoch 70/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.6740 - acc: 0.8173 - val_loss: 6.6579 - val_acc: 0.5797
#
# Epoch 00070: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-070-0.579688.h5
# Epoch 71/80
# 70/70 [==============================] - 3s 39ms/step - loss: 9.5606 - acc: 0.8241 - val_loss: 5.9192 - val_acc: 0.6266
# Epoch 72/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.4748 - acc: 0.8222 - val_loss: 6.6161 - val_acc: 0.5820
# Epoch 73/80
# 70/70 [==============================] - 3s 38ms/step - loss: 9.2934 - acc: 0.8348 - val_loss: 5.8926 - val_acc: 0.6281
# Epoch 74/80
# 70/70 [==============================] - 2s 36ms/step - loss: 9.2471 - acc: 0.8321 - val_loss: 6.0223 - val_acc: 0.6195
# Epoch 75/80
# 70/70 [==============================] - 3s 39ms/step - loss: 9.2456 - acc: 0.8300 - val_loss: 6.2690 - val_acc: 0.6023
#
# Epoch 00075: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-075-0.602344.h5
# Epoch 76/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.3030 - acc: 0.8366 - val_loss: 5.8631 - val_acc: 0.6266
# Epoch 77/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.2465 - acc: 0.8396 - val_loss: 5.8151 - val_acc: 0.6312
# Epoch 78/80
# 70/70 [==============================] - 2s 36ms/step - loss: 9.2853 - acc: 0.8315 - val_loss: 5.7805 - val_acc: 0.6352
# Epoch 79/80
# 70/70 [==============================] - 3s 40ms/step - loss: 9.2370 - acc: 0.8335 - val_loss: 5.7802 - val_acc: 0.6344
# Epoch 80/80
# 70/70 [==============================] - 2s 35ms/step - loss: 9.1962 - acc: 0.8330 - val_loss: 5.8647 - val_acc: 0.6281
#
# Epoch 00080: saving model to /home/ubuntu/Vineet/repo/saved_models/audio_open/10/hp3/model-080-0.628125.h5
